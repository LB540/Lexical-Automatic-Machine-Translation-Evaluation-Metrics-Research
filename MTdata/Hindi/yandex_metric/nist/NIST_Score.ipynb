# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import nltk

# %%
ref=['विज्ञान तब शुरू होता है जब तुम"क्यों" और "कैसे" पूछते हो।']
x=' '.join(ref).split()
x
# Out:
# ['विज्ञान',
#  'तब',
#  'शुरू',
#  'होता',
#  'है',
#  'जब',
#  'तुम"क्यों"',
#  'और',
#  '"कैसे"',
#  'पूछते',
#  'हो।']

# %%
hyp=['तुम पूछते हो कि क्यों, और कैसे पूछते हो।']
y=' '.join(hyp).split()
y
# Out:
# ['तुम', 'पूछते', 'हो', 'कि', 'क्यों,', 'और', 'कैसे', 'पूछते', 'हो।']

# %%
from nltk.translate import nist_score

# %%
nltk.translate.nist_score.sentence_nist([x],y, n=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9d7d64aa1d18> in <cell line: 1>()
# ----> 1 nltk.translate.nist_score.sentence_nist([x],y, n=4)
#
# NameError: name 'x' is not defined

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk import word_tokenize
from nltk.translate import nist_score
# translated_file = "/content/drive/MyDrive/NLP/@SMT/results/Lample-Smt/Unsupervised/test.hi.hyp.tok"
# reference_file = "/content/drive/MyDrive/NLP/@SMT/results/refernce.txt"

# translated_file = "/content/drive/MyDrive/MTE_Files/METEOR/parallel-n/hindi.txt"
# reference_file = "/content/drive/MyDrive/MTE_Files/METEOR/parallel-n/english.txt"

# translated_file = "/content/drive/MyDrive/MTdata/hypothesis(machine).txt"
# reference_file = "/content/drive/MyDrive/MTdata/references(human).txt"

translated_file = "/content/drive/MyDrive/MTdata/Hindi/yandex_hypothesis.txt"
reference_file = "/content/drive/MyDrive/MTdata/Hindi/references(human).txt"

f5 = open('/content/nist_score_ur1-yh.txt', "a+")
with open(translated_file, "r") as f1, open(reference_file, "r") as f2:
  lines1 = [line.rstrip('\n') for line in f1]
  print(len(lines1))
  lines2 = [line.rstrip('\n') for line in f2]
  print(len(lines2))
  for l1,l2 in zip(lines1,lines2):
    tokens_ref=[word_tokenize(l2)]
    #print(tokens_ref)
    tokens_translate=word_tokenize(l1)
    #print(tokens_translate)
    score = nltk.translate.nist_score.sentence_nist(tokens_ref, tokens_translate,n=4)
    f5.write(str(score)+'\n')
f5.close()
# Out:
# 24
# 24

# %%
from sklearn import preprocessing
import numpy as np

# %%
file = "/content/drive/MyDrive/MTdata/Hindi/yandex_metric/nist/nist_score_ur1-yh.txt"
with open(file, 'r') as f:
  lines = [line.rstrip('\n') for line in f]
  print(lines)
  lst_int = [float(i) for i in lines]
  print(lst_int)
  # m_score = list(lst_int)
  normalized_arr = preprocessing.normalize([lst_int])
  # print(type(normalized_arr))
  # print(type(list(normalized_arr[0])))
  # print(type(normalized_arr[0]))
  m_score = list(normalized_arr[0])
  print(m_score)
  # up_score = []
  # for i in m_score:
  #   up_score.append(i)
  # print(up_score)
# Out:
# ['1.6042028126043453', '1.729050000786716', '3.001516826196961', '2.4314672257856773', '1.707895254526658', '0.9730810182559247', '3.077420978099755', '1.992544463614434', '2.584962500721156', '3.373498810441457', '3.408868326544342', '3.611888147602563', '3.3671052714797134', '2.2260666923142214', '3.6953535526320773', '2.415947705372627', '2.5945737139779728', '1.859835948353446', '2.9074883499680007', '3.1507782777313613', '3.6875368890488676', '3.6777015124779724', '2.926850532179716', '2.1139542422010487']
# [1.6042028126043453, 1.729050000786716, 3.001516826196961, 2.4314672257856773, 1.707895254526658, 0.9730810182559247, 3.077420978099755, 1.992544463614434, 2.584962500721156, 3.373498810441457, 3.408868326544342, 3.611888147602563, 3.3671052714797134, 2.2260666923142214, 3.6953535526320773, 2.415947705372627, 2.5945737139779728, 1.859835948353446, 2.9074883499680007, 3.1507782777313613, 3.6875368890488676, 3.6777015124779724, 2.926850532179716, 2.1139542422010487]
# [0.11793282255516485, 0.127110952137496, 0.22065623403661958, 0.17874908997432618, 0.1255557629075029, 0.07153596176001634, 0.22623632079823047, 0.14648172339208668, 0.19003328102535302, 0.24800245547255215, 0.2506026422030889, 0.26552762571759275, 0.2475324350424977, 0.16364908860523508, 0.2716635773089383, 0.17760817385534608, 0.1907398484859323, 0.13672566907098413, 0.2137437392353918, 0.2316291759488429, 0.27108893600293316, 0.27036588919689025, 0.21516714828386985, 0.15540715212342782]

# %%
file = "/content/drive/MyDrive/MTdata/Hindi/yandex_score.txt"
with open(file, 'r') as f:
  lines = [line.rstrip('\n') for line in f]
  lst_dble = [float(i) for i in lines]
  print((lst_dble))
# Out:
# [0.8, 0.8, 0.9, 0.9, 0.6, 0.9, 0.7, 0.8, 0.9, 1.0, 0.9, 0.6, 0.8, 0.8, 0.9, 0.9, 0.9, 0.7, 0.8, 0.8, 0.8, 0.7, 0.8, 1.0]

# %%
import pandas as pd
from scipy.stats import pearsonr

corr, _ = pearsonr(m_score, lst_dble)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: -0.028
