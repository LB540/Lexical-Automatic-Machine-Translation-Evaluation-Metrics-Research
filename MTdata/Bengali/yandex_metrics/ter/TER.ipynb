# %%
qfrom google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/NLP/@SMT/results/USMT
# Out:
# /content/drive/.shortcut-targets-by-id/17P1p7VqCPwRkyqNN5NdG-2IU5CLO5HuP/NLP/@SMT/results/USMT

# %%
#-------- Installation
# !git clone https://github.com/BramVanroy/pyter.git
# %cd pyter
# !pip install -e .
# Out:
# Cloning into 'pyter'...
# remote: Enumerating objects: 212, done.
# remote: Total 212 (delta 0), reused 0 (delta 0), pack-reused 212
# Receiving objects: 100% (212/212), 38.75 KiB | 650.00 KiB/s, done.
# Resolving deltas: 100% (101/101), done.
# /content/pyter
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/pyter
#   Preparing metadata (setup.py) ... done
# Installing collected packages: pyter3
#   Running setup.py develop for pyter3
# Successfully installed pyter3-0.3

# %%
import pyter

# %%
ref = u'SAUDI ARABIA denied THIS WEEK information published in the AMERICAN new york times'.split()

# %%
hyp = u'THIS WEEK THE SAUDIS denied information published in the new york times'.split()

# %%
'%.3f' % pyter.ter(hyp, ref)
# Out:
# '0.308'

# %%
from nltk import word_tokenize 
import nltk
nltk.download('punkt')

# translated_file = "/content/drive/MyDrive/DataAugment/eda/en-ta/ta_base-sr-ri-rs-rd.trasnlated.ta"
# translated_file = "/content/drive/MyDrive/MTE_Files/TER/translated_sentences.txt"
# reference_file = "/content/drive/MyDrive/DataAugment/eda/en-ta/test_ta_en.ta"
# reference_file="/content/drive/MyDrive/MTE_Files/TER/source.txt"


# translated_file = "/content/drive/MyDrive/MTdata/hypothesis(machine).txt"  # Hindi
# reference_file="/content/drive/MyDrive/MTdata/references(human).txt"

# translated_file = "/content/drive/MyDrive/MTdata/Bengali/benHyp.txt"    # Bengali
# reference_file="/content/drive/MyDrive/MTdata/Bengali/benRef.txt"


translated_file = "/content/drive/MyDrive/MTdata/Bengali/benHyp(Machine) - Yandex translate.txt"   # Bengali
reference_file="/content/drive/MyDrive/MTdata/Bengali/benRef(Human).txt"


f5 = open('/content/ter_score_ur1-yb.txt', "a+")
with open(translated_file, "r") as f1, open(reference_file, "r") as f2:
  lines1 = [line.rstrip('\n') for line in f1]
  print(len(lines1))
  lines2 = [line.rstrip('\n') for line in f2]
  print(len(lines2))
  for l1,l2 in zip(lines1,lines2):
    tokens_ref=[word_tokenize(l2)]
    #print(tokens_ref)
    tokens_translate=word_tokenize(l1)
    #print(tokens_translate)
    score ='%.3f' % pyter.ter(tokens_translate, tokens_ref)
    f5.write(str(score)+'\n')
f5.close()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 21
# 21

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
hello = open("/content/source.txt","r",encoding='UTF-8')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-f00ef063298d> in <cell line: 1>()
# ----> 1 hello = open("/content/source.txt","r",encoding='UTF-8')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/source.txt'

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-f572d396fae9> in <cell line: 1>()
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
# open("/content/drive/MyDrive/MTE_Files/source.txt","r")
with open("/content/drive/MyDrive/MTE_Files/source.txt","r") as f: 
    print(f.read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-cba2a8b8e954> in <cell line: 2>()
#       1 # open("/content/drive/MyDrive/MTE_Files/source.txt","r")
# ----> 2 with open("/content/drive/MyDrive/MTE_Files/source.txt","r") as f:
#       3     print(f.read())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/MTE_Files/source.txt'

# %%
with open("/content/drive/MyDrive/MTE_Files/translated_sentences.txt","r") as f: 
    print(f.read())
# Out:
# आपसे मिलकर अच्छा लगा
# लाखों साल पहले हुई थी दिनासौरस की मौत, जब धरती से टकराया था एस्टेरॉयड

# %%
from sklearn import preprocessing

# %%
# f5 = open('/content/ter_score_ur1.txt', "a+")
# with open(translated_file, "r") as f1, open(reference_file, "r") as f2:
#   lines1 = [line.rstrip('\n') for line in f1]
#   print(len(lines1))
#   lines2 = [line.rstrip('\n') for line in f2]
#   print(len(lines2))
#   for l1,l2 in zip(lines1,lines2):
#     tokens_ref=[word_tokenize(l2)]
#     #print(tokens_ref)
#     tokens_translate=word_tokenize(l1)
#     #print(tokens_translate)
#     score ='%.3f' % pyter.ter(tokens_translate, tokens_ref)
#     f5.write(str(score)+'\n')
# f5.close()
# Out:
# 0

# %%
from sklearn import preprocessing
import numpy as np

# %%
file = "/content/drive/MyDrive/MTdata/Bengali/yandex_metrics/ter/ter_score_ur1-yb.txt"
with open(file, 'r') as f:
  lines = [line.rstrip('\n') for line in f]
  # print(lines)
  lst_int = [int(eval(i)) for i in lines]
  # print(lst_int)
  normalized_arr = preprocessing.normalize([lst_int])
  # print(type(normalized_arr))
  # print(type(list(normalized_arr[0])))
  # print(type(normalized_arr[0]))
  m_score = list(normalized_arr[0])
  print(m_score)
  # print(up_score)
# Out:
# [0.21501647626876533, 0.12900988576125919, 0.21501647626876533, 0.17201318101501226, 0.17201318101501226, 0.17201318101501226, 0.17201318101501226, 0.15051153338813572, 0.17201318101501226, 0.25801977152251837, 0.27952141914939493, 0.17201318101501226, 0.15051153338813572, 0.15051153338813572, 0.1935148286418888, 0.21501647626876533, 0.30102306677627144, 0.25801977152251837, 0.322524714403148, 0.1935148286418888, 0.3440263620300245]

# %%
file = "/content/drive/MyDrive/MTdata/Bengali/score_yandex.txt"
with open(file, 'r') as f:
  lines = [line.rstrip('\n') for line in f]
  lst_dble = [float(i) for i in lines]
  print((lst_dble))
  # lst_int = [eval(i) for i in lines]
  # print(lst_int)
  # np.asarray(lines, dtype=float)
# Out:
# [0.4, 0.4, 0.6, 0.7, 0.4, 0.3, 0.3, 0.8, 0.4, 0.5, 0.9, 0.5, 0.3, 0.6, 0.6, 0.6, 0.7, 0.8, 0.6, 0.9, 0.6]

# %%
# Pearson Correlation

import pandas as pd
from scipy.stats import pearsonr

corr, _ = pearsonr(up_score, lst_dble)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: -0.387
