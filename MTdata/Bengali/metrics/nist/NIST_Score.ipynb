# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import nltk

# %%
ref=['विज्ञान तब शुरू होता है जब तुम"क्यों" और "कैसे" पूछते हो।']
x=' '.join(ref).split()
x
# Out:
# ['विज्ञान',
#  'तब',
#  'शुरू',
#  'होता',
#  'है',
#  'जब',
#  'तुम"क्यों"',
#  'और',
#  '"कैसे"',
#  'पूछते',
#  'हो।']

# %%
hyp=['तुम पूछते हो कि क्यों, और कैसे पूछते हो।']
y=' '.join(hyp).split()
y
# Out:
# ['तुम', 'पूछते', 'हो', 'कि', 'क्यों,', 'और', 'कैसे', 'पूछते', 'हो।']

# %%
from nltk.translate import nist_score

# %%
nltk.translate.nist_score.sentence_nist([x],y, n=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-9d7d64aa1d18> in <cell line: 1>()
# ----> 1 nltk.translate.nist_score.sentence_nist([x],y, n=4)
#
# NameError: name 'x' is not defined

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk import word_tokenize
from nltk.translate import nist_score
# translated_file = "/content/drive/MyDrive/NLP/@SMT/results/Lample-Smt/Unsupervised/test.hi.hyp.tok"
# reference_file = "/content/drive/MyDrive/NLP/@SMT/results/refernce.txt"

# translated_file = "/content/drive/MyDrive/MTE_Files/METEOR/parallel-n/hindi.txt"
# reference_file = "/content/drive/MyDrive/MTE_Files/METEOR/parallel-n/english.txt"

# translated_file = "/content/drive/MyDrive/MTdata/hypothesis(machine).txt"
# reference_file = "/content/drive/MyDrive/MTdata/references(human).txt"

translated_file = "/content/drive/MyDrive/MTdata/Bengali/benHyp(Machine) - Google translate.txt"   # Bengali
reference_file="/content/drive/MyDrive/MTdata/Bengali/benRef(Human).txt"

f5 = open('/content/nist_score_ur1.txt', "a+")
with open(translated_file, "r") as f1, open(reference_file, "r") as f2:
  lines1 = [line.rstrip('\n') for line in f1]
  print(len(lines1))
  lines2 = [line.rstrip('\n') for line in f2]
  print(len(lines2))
  for l1,l2 in zip(lines1,lines2):
    tokens_ref=[word_tokenize(l2)]
    #print(tokens_ref)
    tokens_translate=word_tokenize(l1)
    #print(tokens_translate)
    score = nltk.translate.nist_score.sentence_nist(tokens_ref, tokens_translate,n=4)
    f5.write(str(score)+'\n')
f5.close()
# Out:
# 21
# 21

# %%
from sklearn import preprocessing
import numpy as np

# %%
file = "/content/drive/MyDrive/MTdata/Bengali/metrics/nist/nist_score_ur1-b.txt"
with open(file, 'r') as f:
  lines = [line.rstrip('\n') for line in f]
  print(lines)
  lst_int = [float(i) for i in lines]
  print(lst_int)
  m_score = list(lst_int)
  print(len(m_score))
  # normalized_arr = preprocessing.normalize([lst_int])
  # print(type(normalized_arr))
  # print(type(list(normalized_arr[0])))
  # print(type(normalized_arr[0]))
  # m_score = list(normalized_arr[0])
  # print(m_score)
  # up_score = []
  # for i in m_score:
  #   up_score.append(i)
  # print(up_score)
# Out:
# ['1.3464372969835736', '1.3934338964335204', '1.1239880943867864', '1.5', '0.37372915454403033', '0.646240625180289', '0.2222222222222222', '1.3268160542213498', '1.0409367241052576', '0.8422064766172813', '1.1949875002403856', '0.3231203125901445', '0.8987681365187772', '2.1164383136702805', '2.1164383136702805', '0.9509775004326938', '0.2541735355182769', '2.5832959668633757', '0.23062877457581984', '2.0196559454753604', '1.6411133737642807']
# [1.3464372969835736, 1.3934338964335204, 1.1239880943867864, 1.5, 0.37372915454403033, 0.646240625180289, 0.2222222222222222, 1.3268160542213498, 1.0409367241052576, 0.8422064766172813, 1.1949875002403856, 0.3231203125901445, 0.8987681365187772, 2.1164383136702805, 2.1164383136702805, 0.9509775004326938, 0.2541735355182769, 2.5832959668633757, 0.23062877457581984, 2.0196559454753604, 1.6411133737642807]
# 21

# %%
file = "/content/drive/MyDrive/MTdata/Bengali/metrics/bleu/ExpScore.txt"
with open(file, 'r') as f:
  lines = [line.rstrip('\n') for line in f]
  lst_dble = [float(i) for i in lines]
  print((lst_dble))
# Out:
# [0.6, 0.5, 0.4, 0.6, 0.7, 0.6, 0.5, 0.4, 0.6, 0.6, 0.4, 0.5, 0.5, 0.7, 0.8, 0.6, 0.6, 0.5, 0.6, 0.8, 0.8]

# %%
import pandas as pd
from scipy.stats import pearsonr

corr, _ = pearsonr(m_score, lst_dble)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.282
