# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import nltk

# %%
ref=['विज्ञान तब शुरू होता है जब तुम"क्यों" और "कैसे" पूछते हो।']
x=' '.join(ref).split()
x
# Out:
# ['विज्ञान',
#  'तब',
#  'शुरू',
#  'होता',
#  'है',
#  'जब',
#  'तुम"क्यों"',
#  'और',
#  '"कैसे"',
#  'पूछते',
#  'हो।']

# %%
hyp=['तुम पूछते हो कि क्यों, और कैसे पूछते हो।']
y=' '.join(hyp).split()
y
# Out:
# ['तुम', 'पूछते', 'हो', 'कि', 'क्यों,', 'और', 'कैसे', 'पूछते', 'हो।']

# %%
from nltk.translate import nist_score

# %%
nltk.translate.nist_score.sentence_nist([x],y, n=4)
# Out:
# 0.9730810182559247

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk import word_tokenize
from nltk.translate import nist_score

translated_file = "/content/drive/MyDrive/MTdata/Telugu/hypo.txt"   # Telugu
reference_file="/content/drive/MyDrive/MTdata/Telugu/ref.txt"

f5 = open('/content/nist_score_ur1.txt', "a+")
with open(translated_file, "r") as f1, open(reference_file, "r") as f2:
  lines1 = [line.rstrip('\n') for line in f1]
  print(len(lines1))
  lines2 = [line.rstrip('\n') for line in f2]
  print(len(lines2))
  for l1,l2 in zip(lines1,lines2):
    tokens_ref=[word_tokenize(l2)]
    #print(tokens_ref)
    tokens_translate=word_tokenize(l1)
    #print(tokens_translate)
    score = nltk.translate.nist_score.sentence_nist(tokens_ref, tokens_translate,n=4)
    f5.write(str(score)+'\n')
f5.close()
# Out:
# 27
# 27

# %%
from sklearn import preprocessing
import numpy as np

# %%
file = "/content/drive/MyDrive/MTdata/Telugu/metrics/nist/nist_score_ur1.txt"
with open(file, 'r') as f:
  lines = [line.rstrip('\n') for line in f]
  print(lines)
  lst_int = [float(i) for i in lines]
  print(lst_int)
  normalized_arr = preprocessing.normalize([lst_int])
  m_score = list(normalized_arr[0])
  print(m_score)
# Out:
# ['1.4408750006555966', '2.2638443518601457', '1.4737926535185155', '2.6575424759098896', '1.9036774610288023', '1.1926018925656026', '1.9019550008653876', '0.26431712272436375', '1.4650839733531946', '0.9225150983032794', '1.960572825208761', '1.911980000384617', '1.6666666666666667', '3.5', '1.6411133737642807', '2.465497223344021', '1.4922532045034094', '2.979123317238989', '1.3215856136218187', '2.1273317835039594', '1.121187463632091', '1.6317362320441176', '2.930167946706389', '2.016061112072653', '2.0228226254493262', '1.8075909303668036', '2.5153826131779398']
# [1.4408750006555966, 2.2638443518601457, 1.4737926535185155, 2.6575424759098896, 1.9036774610288023, 1.1926018925656026, 1.9019550008653876, 0.26431712272436375, 1.4650839733531946, 0.9225150983032794, 1.960572825208761, 1.911980000384617, 1.6666666666666667, 3.5, 1.6411133737642807, 2.465497223344021, 1.4922532045034094, 2.979123317238989, 1.3215856136218187, 2.1273317835039594, 1.121187463632091, 1.6317362320441176, 2.930167946706389, 2.016061112072653, 2.0228226254493262, 1.8075909303668036, 2.5153826131779398]
# [0.1392318737622959, 0.21875547210706203, 0.14241270935585928, 0.2567985552913811, 0.18395251483820005, 0.11524122222872726, 0.1837860733662306, 0.025540986031145865, 0.14157118885140021, 0.08914271234654812, 0.1894503187140113, 0.18475478992172176, 0.1610501416372523, 0.3382052974382298, 0.1585809247725158, 0.2382412062154841, 0.14419655396635062, 0.287872939317708, 0.12770493015572934, 0.2055642510256447, 0.10834043989191595, 0.1576748107712049, 0.2831423777028004, 0.1948121565891943, 0.19546552220139152, 0.1746676652146718, 0.2430616356745134]

# %%
file = "/content/drive/MyDrive/MTdata/Telugu/metrics/bleu/expert_score.txt"
with open(file, 'r') as f:
  lines = [line.rstrip('\n') for line in f]
  lst_dble = [float(i) for i in lines]
  print((lst_dble))
# Out:
# [0.4, 0.8, 0.5, 0.9, 0.5, 0.6, 0.8, 0.3, 0.4, 0.7, 0.6, 0.4, 0.7, 0.6, 0.7, 0.8, 0.6, 0.6, 0.7, 0.3, 0.7, 0.3, 0.5, 0.7, 0.8, 0.2, 0.6]

# %%
import pandas as pd
from scipy.stats import pearsonr

corr, _ = pearsonr(m_score, lst_dble)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.246
